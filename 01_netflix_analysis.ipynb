# %% [markdown]
# # """ Mini Project 2: Netflix Movies Analysis
# Dataset: netflix_titles.csv
# Tasks:
# 1.Load the dataset and clean null values.
# 2.How many movies vs TV shows?
# 3.Top 10 directors with most titles.
# 4.Number of titles per year.
# 5.Filter:Titles from India after 2015 with rating 'TV-14' or 'R'."""

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = r"C:\Users\sanjay pallav\Documents\Python banny\Pandas_Mini_Projects\datasets\netflix_titles.csv"

# Load the dataset
data = pd.read_csv(file_path, encoding='utf-8')

#Display first few rows to verify
print(data.head())
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Cleaning all the null values in the dataset by dropping them
data.dropna(inplace=True)

# Checking if all the null values are cleaned or not.
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# Checking how many movies vs Tv shows using value
data["type"].value_counts()
# Out:
# Movie      5185
# TV Show     147
# Name: type, dtype: int64

# %%
# Listing out the top 10 directors with most movie titles
data["director"].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
# Listing out the number of titles per year
data["release_year"].value_counts().sort_index()
# Out:
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: release_year, Length: 74, dtype: int64

# %%
# Optional: Method 2 using loop and Matplotlib (messy but exploratory)
# This was just an experiment to try visualizing via manual looping

for years in data["release_year"].unique():
    count = data[data["release_year"]==years]["title"]
    plt.plot(count)
    plt.show()
# Out:
# C:\Users\sanjay pallav\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52572 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\sanjay pallav\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\sanjay pallav\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\sanjay pallav\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 49324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\sanjay pallav\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# Optional: Method 3 - Clean  one-liner with Matplotlib
plt.plot(data["release_year"].unique(), [data[data["release_year"] == y]["title"].count() for y in data["release_year"].unique()], '-o')

# %%
# Filter:Titles from India after 2015 with rating 'TV-14' or 'R'.
data[(data["country"]=="India")&(data["release_year"]>2015)&(data["rating"].isin(["TV-14", "R"]))]
# Out:
#      show_id   type                         title              director  \
# 105     s106  Movie              Angamaly Diaries  Lijo Jose Pellissery
# 118     s119  Movie                       Gurgaon         Shanker Raman
# 126     s127  Movie                       Shikara    Vidhu Vinod Chopra
# 190     s191  Movie                    Thimmarusu     Sharan Koppisetty
# 518     s519  Movie  Har Kisse Ke Hisse: Kaamyaab          Hardik Mehta
# ...      ...    ...                           ...                   ...
# 8671   s8672  Movie                     Veerappan       Ram Gopal Varma
# 8672   s8673  Movie             Veerey Ki Wedding           Ashu Trikha
# 8680   s8681  Movie        Viswasapoorvam Mansoor   P.T. Kunju Muhammad
# 8683   s8684  Movie                 Vodka Diaries     Kushal Srivastava
# 8687   s8688  Movie              Waarrior Savitri            Param Gill
#
#                                                    cast country  \
# ...

# %% [markdown]
# ---
# ## Project Summary
#
# This mini project involved analyzing the Netflix dataset using the Pandas library for data manipulation and filtering, along with basic Matplotlib visualizations.
#
# Key tasks completed:
# - cleaned and explored the dataset
# - Answered specific analytical questions usig Pandas
# - Visualized data to understand trends
# - Tried multiple methods to solve one task(task 4) to explore and learn different approaches
#
# **Note**: Some code cells are marked as _Optional_ to showcase experimentation with alternative methods. Only the most efficient or clean solution is considered final.
#
# ---
